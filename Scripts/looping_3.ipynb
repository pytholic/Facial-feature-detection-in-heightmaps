# %%
import os
import glob

# %%
for folder in glob.glob(r"Z:\original\asmc\raja_angiography_2111_2202/[!_]*"):
    #print(folder)
    # !MarsTool.exe meshgen -M -C --no-mesh-out {folder} -O E:\skia_projects\Facial-feature-detection-in-heightmaps\data8\data_volume
# Out:
# body target : HEAD
# current working directory : E:\skia_projects\Facial-feature-detection-in-heightmaps\MarsTool
# output dir specified to : E:\skia_projects\Facial-feature-detection-in-heightmaps\data8\data_volume
# reading FileSystem of Z:\original\asmc\raja_angiography_2111_2202\15729132_artery
# 1 directories / 108 dicom files
# Reading dicom series...
# extracting Dicom series from Z:\original\asmc\raja_angiography_2111_2202\15729132_artery
# grouping dicom series : 1.3.12.2.1107.5.1.4.74211.30000021092822381416600041464 / Orbit~T1-3sec  3.0  Br40
# 1 dicom series found. creating meshes of each series
# WORKING series(1.3.12.2.1107.5.1.4.74211.30000021092822381416600041464 in Z:\original\asmc\raja_angiography_2111_2202\15729132_artery)
# skin segmentation ...
#   saved mask volume : E:\skia_projects\Facial-feature-detection-in-heightmaps\data8\data_volume\1.3.12.2.1107.5.1.4.74211.30000021092822381416600041464.mask.vol
# skipping
# genertaed mesh :
# body target : HEAD
# ...

# %% [markdown]
# To exclude manifests files (files starting with _ ) with glob, we can use:
#
# ```python
# files = glob.glob('files_path/[!_]*')
# ```
#
# `[!_]` part helps in ignoring the files starting with an underscore, which I deliberately inserted in the unwanted files.

# %%
for volume in glob.glob("E:/skia_projects/Facial-feature-detection-in-heightmaps/data8/data_volume/*.vol"):
    #print(volume)
    # !MarsTool.exe depth -i 1 -d A {volume}
# Out:
# writing height map image : E:/skia_projects/Facial-feature-detection-in-heightmaps/data8/data_volume\1.2.840.113619.2.340.3.397182486.343.1640898348.720.3.mask.vol.height.ANTERIOR.png
# writing height map image : E:/skia_projects/Facial-feature-detection-in-heightmaps/data8/data_volume\1.3.12.2.1107.5.1.4.155391.30000021010123385327000006055.mask.vol.height.ANTERIOR.png
# writing height map image : E:/skia_projects/Facial-feature-detection-in-heightmaps/data8/data_volume\1.3.12.2.1107.5.1.4.155391.30000021010123385327000006239.mask.vol.height.ANTERIOR.png
# writing height map image : E:/skia_projects/Facial-feature-detection-in-heightmaps/data8/data_volume\1.3.12.2.1107.5.1.4.155391.30000021111022202982600050834.mask.vol.height.ANTERIOR.png
# writing height map image : E:/skia_projects/Facial-feature-detection-in-heightmaps/data8/data_volume\1.3.12.2.1107.5.1.4.155391.30000021111022202982600051596.mask.vol.height.ANTERIOR.png
# ...
