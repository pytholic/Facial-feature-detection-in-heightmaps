# %%
import os
import glob

# %%
for folder in glob.glob("E:/skia_projects/Facial-feature-detection-in-heightmaps/data/test_data/*"):
    # !MarsTool.exe meshgen -M -C --no-mesh-out {folder} -O E:\skia_projects\Facial-feature-detection-in-heightmaps\data
# Out:
# body target : HEAD
# current working directory : E:\skia_projects\Facial-feature-detection-in-heightmaps\MarsTool
# output dir specified to : E:\skia_projects\Facial-feature-detection-in-heightmaps\data
# reading FileSystem of E:/skia_projects/Facial-feature-detection-in-heightmaps/data/test_data\11143712_KIM_SANGJOON
# 1 directories / 172 dicom files
# Reading dicom series...
# extracting Dicom series from E:/skia_projects/Facial-feature-detection-in-heightmaps/data/test_data\11143712_KIM_SANGJOON
# grouping dicom series : 1.3.12.2.1107.5.1.4.66417.30000021090323410187400018283 / Post  3.0  I40f  1
# none-axial image excluded : E:/skia_projects/Facial-feature-detection-in-heightmaps/data/test_data\11143712_KIM_SANGJOON\11143712_098.dcm
# none-axial image excluded : E:/skia_projects/Facial-feature-detection-in-heightmaps/data/test_data\11143712_KIM_SANGJOON\11143712_099.dcm
# ...

# %%
for volume in glob.glob("E:/skia_projects/Facial-feature-detection-in-heightmaps/data/*.vol"):
    #print(volume)
    # !MarsTool.exe depth -i 1 -d A {volume}
# Out:
# writing height map image : E:/skia_projects/Facial-feature-detection-in-heightmaps/data\1.3.12.2.1107.5.1.4.66417.30000021090323410187400018283.mask.vol.height.ANTERIOR.png
# writing height map image : E:/skia_projects/Facial-feature-detection-in-heightmaps/data\1.3.12.2.1107.5.1.4.75800.30000021070522115055600092126.mask.vol.height.ANTERIOR.png
