# %% [markdown]
# # Import libraries

# %%
import mediapipe
import cv2
import matplotlib.pyplot as plt
import numpy as np
import glob
import shutil
import os
#from mpl_toolkits.mplot3d import Axes3D

# %%
dim = (224, 224)
gamma = 0.4

# %%
def adjust_gamma(image, gamma=1.0):

    invGamma = 1.0 / gamma
    table = np.array([((i / 255.0) ** invGamma) * 255
        for i in np.arange(0, 256)]).astype("uint8")

    return cv2.LUT(image, table)

# %%
correct = 0
wrong = 0

for idx, file in enumerate(glob.glob("./data_heightmap/*.png")):
    print(file)
    image = cv2.imread(file)
    resized = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
    adjusted = adjust_gamma(resized, gamma=gamma)
    enhanced = cv2.detailEnhance(adjusted, sigma_s=25, sigma_r=0.15)
    img = enhanced.copy()
    
    # Save enhanced image
    cv2.imwrite(f"./results/enhanced/enhanced_{idx+1}.png", img)
    
    mp_face_mesh = mediapipe.solutions.face_mesh
    face_mesh = mp_face_mesh.FaceMesh(static_image_mode=True, refine_landmarks=True)
    results = face_mesh.process(img)
    landmarks = results.multi_face_landmarks[0]
    
    
    ### LANDMARK DETECTION ###
    for landmark in landmarks.landmark:
        x = landmark.x
        y = landmark.y
        relative_x = int(x * img.shape[1])
        relative_y = int(y * img.shape[0]) # To denormalize values
        cv2.circle(img, (relative_x, relative_y), radius=2, color=(0, 0, 255), thickness=-1)
   
    # Save landmark image
    cv2.imwrite(f"./results//landmarks/landmarks_{idx+1}.png", img)

    
    ### CONTOUR DETECTION ###
    img = enhanced.copy()
    for source_idx, target_idx in mp_face_mesh.FACEMESH_CONTOURS:
    
        source = landmarks.landmark[source_idx]
        target = landmarks.landmark[target_idx]

        relative_source = (int(source.x * img.shape[1]), int(source.y * img.shape[0]))
        relative_target = (int(target.x * img.shape[1]), int(target.y * img.shape[0]))

        cv2.line(img, relative_source, relative_target, color=(0, 0, 255), thickness=2)
    
    # Save contour image
    cv2.imwrite(f"./results/contours/contour_{idx+1}.png", img)
    
    
    ### FACE MESH ESTIMATION ###
    img = enhanced.copy()
    for source_idx, target_idx in mp_face_mesh.FACEMESH_TESSELATION:

        source = landmarks.landmark[source_idx]
        target = landmarks.landmark[target_idx]

        relative_source = (int(source.x * img.shape[1]), int(source.y * img.shape[0]))
        relative_target = (int(target.x * img.shape[1]), int(target.y * img.shape[0]))

        cv2.line(img, relative_source, relative_target, color=(255, 255, 255), thickness=1)
    
    # Save face mesh image
    cv2.imwrite(f"./results/meshes/mesh_{idx+1}.png", img)
# Out:
# ./data_heightmap\1.png
# ./data_heightmap\10.png
# ./data_heightmap\100.png
# ./data_heightmap\101.png
# ./data_heightmap\102.png
# ./data_heightmap\103.png
# ./data_heightmap\104.png
# ./data_heightmap\105.png
# ./data_heightmap\106.png
# ./data_heightmap\107.png
# ./data_heightmap\108.png
# ./data_heightmap\109.png
# ./data_heightmap\11.png
# ./data_heightmap\110.png
# ./data_heightmap\111.png
# ./data_heightmap\112.png
# ./data_heightmap\113.png
# ./data_heightmap\114.png
# ./data_heightmap\115.png
# ./data_heightmap\116.png
# ./data_heightmap\117.png
# ./data_heightmap\118.png
# ./data_heightmap\119.png
# ./data_heightmap\12.png
# ./data_heightmap\120.png
# ./data_heightmap\121.png
# ./data_heightmap\122.png
# ./data_heightmap\123.png
# ./data_heightmap\124.png
# ./data_heightmap\125.png
# ./data_heightmap\126.png
# ./data_heightmap\127.png
# ./data_heightmap\128.png
# ./data_heightmap\129.png
# ./data_heightmap\13.png
# ./data_heightmap\130.png
# ./data_heightmap\131.png
# ./data_heightmap\132.png
# ./data_heightmap\133.png
# ./data_heightmap\134.png
# ./data_heightmap\135.png
# ./data_heightmap\136.png
# ./data_heightmap\137.png
# ./data_heightmap\138.png
# ./data_heightmap\139.png
# ./data_heightmap\14.png
# ./data_heightmap\140.png
# ./data_heightmap\141.png
# ./data_heightmap\142.png
# ./data_heightmap\143.png
# ./data_heightmap\144.png
# ./data_heightmap\145.png
# ./data_heightmap\146.png
# ./data_heightmap\147.png
# ./data_heightmap\148.png
# ./data_heightmap\149.png
# ./data_heightmap\15.png
# ./data_heightmap\150.png
# ./data_heightmap\151.png
# ./data_heightmap\152.png
# ./data_heightmap\153.png
# ./data_heightmap\154.png
# ./data_heightmap\155.png
# ./data_heightmap\156.png
# ./data_heightmap\157.png
# ./data_heightmap\158.png
# ./data_heightmap\159.png
# ./data_heightmap\16.png
# ./data_heightmap\160.png
# ./data_heightmap\161.png
# ./data_heightmap\162.png
# ./data_heightmap\163.png
# ./data_heightmap\164.png
# ./data_heightmap\165.png
# ./data_heightmap\166.png
# ./data_heightmap\167.png
# ./data_heightmap\168.png
# ./data_heightmap\169.png
# ./data_heightmap\17.png
# ./data_heightmap\170.png
# ./data_heightmap\171.png
# ./data_heightmap\172.png
# ./data_heightmap\173.png
# ./data_heightmap\174.png
# ./data_heightmap\175.png
# ./data_heightmap\176.png
# ./data_heightmap\177.png
# ./data_heightmap\178.png
# ./data_heightmap\179.png
# ./data_heightmap\18.png
# ./data_heightmap\180.png
# ./data_heightmap\181.png
# ./data_heightmap\182.png
# ./data_heightmap\183.png
# ./data_heightmap\184.png
# ./data_heightmap\185.png
# ./data_heightmap\186.png
# ./data_heightmap\187.png
# ./data_heightmap\188.png
# ./data_heightmap\189.png
# ./data_heightmap\19.png
# ./data_heightmap\190.png
# ./data_heightmap\191.png
# ./data_heightmap\192.png
# ./data_heightmap\193.png
# ./data_heightmap\194.png
# ./data_heightmap\195.png
# ./data_heightmap\196.png
# ./data_heightmap\197.png
# ./data_heightmap\198.png
# ./data_heightmap\199.png
# ./data_heightmap\2.png
# ./data_heightmap\20.png
# ./data_heightmap\200.png
# ./data_heightmap\201.png
# ./data_heightmap\202.png
# ./data_heightmap\203.png
# ./data_heightmap\204.png
# ./data_heightmap\205.png
# ./data_heightmap\206.png
# ./data_heightmap\207.png
# ./data_heightmap\208.png
# ./data_heightmap\209.png
# ./data_heightmap\21.png
# ./data_heightmap\210.png
# ./data_heightmap\211.png
# ./data_heightmap\212.png
# ./data_heightmap\213.png
# ./data_heightmap\214.png
# ./data_heightmap\215.png
# ./data_heightmap\216.png
# ./data_heightmap\217.png
# ./data_heightmap\218.png
# ./data_heightmap\219.png
# ./data_heightmap\22.png
# ./data_heightmap\220.png
# ./data_heightmap\221.png
# ./data_heightmap\222.png
# ./data_heightmap\223.png
# ./data_heightmap\224.png
# ./data_heightmap\225.png
# ./data_heightmap\226.png
# ./data_heightmap\227.png
# ./data_heightmap\228.png
# ./data_heightmap\229.png
# ./data_heightmap\23.png
# ./data_heightmap\230.png
# ./data_heightmap\231.png
# ./data_heightmap\232.png
# ./data_heightmap\233.png
# ./data_heightmap\234.png
# ./data_heightmap\235.png
# ./data_heightmap\236.png
# ./data_heightmap\237.png
# ./data_heightmap\238.png
# ./data_heightmap\239.png
# ./data_heightmap\24.png
# ./data_heightmap\240.png
# ./data_heightmap\241.png
# ./data_heightmap\242.png
# ./data_heightmap\243.png
# ./data_heightmap\244.png
# ./data_heightmap\245.png
# ./data_heightmap\246.png
# ./data_heightmap\247.png
# ./data_heightmap\248.png
# ./data_heightmap\25.png
# ./data_heightmap\26.png
# ./data_heightmap\27.png
# ./data_heightmap\28.png
# ./data_heightmap\29.png
# ./data_heightmap\3.png
# ./data_heightmap\30.png
# ./data_heightmap\31.png
# ./data_heightmap\32.png
# ./data_heightmap\33.png
# ./data_heightmap\34.png
# ./data_heightmap\35.png
# ./data_heightmap\36.png
# ./data_heightmap\37.png
# ./data_heightmap\38.png
# ./data_heightmap\39.png
# ./data_heightmap\4.png
# ./data_heightmap\40.png
# ./data_heightmap\41.png
# ./data_heightmap\42.png
# ./data_heightmap\43.png
# ./data_heightmap\44.png
# ./data_heightmap\45.png
# ./data_heightmap\46.png
# ./data_heightmap\47.png
# ./data_heightmap\48.png
# ./data_heightmap\49.png
# ./data_heightmap\5.png
# ./data_heightmap\50.png
# ./data_heightmap\51.png
# ./data_heightmap\52.png
# ./data_heightmap\53.png
# ./data_heightmap\54.png
# ./data_heightmap\55.png
# ./data_heightmap\56.png
# ./data_heightmap\57.png
# ./data_heightmap\58.png
# ./data_heightmap\59.png
# ./data_heightmap\6.png
# ./data_heightmap\60.png
# ./data_heightmap\61.png
# ./data_heightmap\62.png
# ./data_heightmap\63.png
# ./data_heightmap\64.png
# ./data_heightmap\65.png
# ./data_heightmap\66.png
# ./data_heightmap\67.png
# ./data_heightmap\68.png
# ./data_heightmap\69.png
# ./data_heightmap\7.png
# ./data_heightmap\70.png
# ./data_heightmap\71.png
# ./data_heightmap\72.png
# ./data_heightmap\73.png
# ./data_heightmap\74.png
# ./data_heightmap\75.png
# ./data_heightmap\76.png
# ./data_heightmap\77.png
# ./data_heightmap\78.png
# ./data_heightmap\79.png
# ./data_heightmap\8.png
# ./data_heightmap\80.png
# ./data_heightmap\81.png
# ./data_heightmap\82.png
# ./data_heightmap\83.png
# ./data_heightmap\84.png
# ./data_heightmap\85.png
# ./data_heightmap\86.png
# ./data_heightmap\87.png
# ./data_heightmap\88.png
# ./data_heightmap\89.png
# ./data_heightmap\9.png
# ./data_heightmap\90.png
# ./data_heightmap\91.png
# ./data_heightmap\92.png
# ./data_heightmap\93.png
# ./data_heightmap\94.png
# ./data_heightmap\95.png
# ./data_heightmap\96.png
# ./data_heightmap\97.png
# ./data_heightmap\98.png
# ./data_heightmap\99.png
